# %% [markdown]
# ## Assessment 2B
# # MDSI Slack Analysis
# ### Juan Pablo Herrera - 12869246

# %%
# Import Libraries
import pandas as pd 
from sqlalchemy import create_engine

# %%
#  Conect to the database 
engine = create_engine("postgresql+psycopg2://dsp2019:oZkK6vgRbvDK@/mdsislack?host=mdsislack.clnutj7nhgyn.us-east-2.rds.amazonaws.com&port=5432")

con = engine.connect()
rs = con.execute('select * from users')
df = pd.DataFrame(rs.fetchall())
df.columns = rs.keys()

print(df)

con.close()
# Out:
# user_id     user_nickname       user_name        user_timezone  \
# 0    U1YEPQMU5          lilianta       Lilian Ta   Australia/Canberra
# 1    U1WP5BRRU        joeysyd123        Joey Liu   Australia/Canberra
# 2    U9ZDY9AKB    sastra.widjaja        Roger Yu   Australia/Canberra
# 3    U9KG4RGMD          13102191   Jorge Pilayre   Australia/Canberra
# 4    U4ELUPRDY     peteholberton  Pete Holberton   Australia/Canberra
# ..         ...               ...             ...                  ...
# 358  U9U1DJQDA          12690184        John HAN  America/Los_Angeles
# 359  U87SVFN95          12457040    Alex Scriven  America/Los_Angeles
# 360  U1YRMP9KR              anuj      Anuj Kapil   Australia/Canberra
# 361  UE9RWSWAK          greetbot        greetbot  America/Los_Angeles
# 362  U9H989TR8  ujashkumar.leuva           Ujash   Australia/Canberra
#
#                                             user_photo  user_is_admin  \
# 0    https://avatars.slack-edge.com/2016-09-03/7598...          False
# 1    https://secure.gravatar.com/avatar/fffe46e0721...          False
# 2    https://secure.gravatar.com/avatar/68c8f6b4f9c...          False
# 3    https://secure.gravatar.com/avatar/ed29657c615...          False
# 4    https://avatars.slack-edge.com/2017-03-08/1512...          False
# ..                                                 ...            ...
# 358  https://secure.gravatar.com/avatar/7f45cfe2ab8...          False
# 359  https://secure.gravatar.com/avatar/a42490d0ed5...          False
# 360  https://secure.gravatar.com/avatar/fc924b84a15...          False
# 361  https://avatars.slack-edge.com/2018-11-20/4850...          False
# 362  https://secure.gravatar.com/avatar/c13b249e3f7...          False
#
#      user_is_owner  user_is_bot  user_is_deleted
# 0            False        False            False
# 1            False        False            False
# 2            False        False            False
# 3            False        False            False
# 4            False        False            False
# ..             ...          ...              ...
# 358          False        False            False
# 359          False        False            False
# 360          False        False            False
# 361          False         True            False
# 362          False        False            False
#
# [363 rows x 9 columns]
